# %%
import pandas as pd
df = pd.read_csv('./PHMtutorial/IMDB.csv', index_col = 0, encoding = 'latin-1')

# %%
df
# Out:
#                                  Title  Rating TotalVotes     Genre1  \
# 1              12 Years a Slave (2013)     8.1    496,092  Biography
# 2                     127 Hours (2010)     7.6    297,075  Adventure
# 3                         50/50 (2011)     7.7    283,935     Comedy
# 4                    About Time (2013)     7.8    225,412     Comedy
# 5                         Amour (2012)     7.9     76,121      Drama
# ..                                 ...     ...        ...        ...
# 114                    Whiplash (2014)     8.5    492,285      Drama
# 115              Wreck-It Ralph (2012)     7.7    295,125  Animation
# 116  X-Men: Days of Future Past (2014)     8.0    560,736     Action
# 117          X-Men: First Class (2011)     7.8    556,713     Action
# 118                    Zootopia (2016)     8.1    309,474  Animation
#
#         Genre2   Genre3  MetaCritic  \
# 1        Drama  History        96.0
# 2    Biography    Drama        82.0
# 3        Drama  Romance        72.0
# 4        Drama  Fantasy         NaN
# 5      Romance      NaN        94.0
# ..         ...      ...         ...
# 114      Music      NaN        88.0
# 115  Adventure   Comedy        72.0
# 116  Adventure   Sci-Fi        74.0
# 117  Adventure   Sci-Fi        65.0
# 118  Adventure   Comedy        78.0
#
#                                                 Budget  Runtime  ï..CVotes10  \
# 1                                         $20,000,000   134 min        75556
# 2                                         $18,000,000    94 min        28939
# 3                                          $8,000,000   100 min        28304
# 4                                         $12,000,000   123 min        38556
# 5                                          $8,900,000   127 min        11093
# ..                                                 ...      ...          ...
# 114                                        $3,300,000   107 min       110404
# 115  Opening Weekend:         49,038,712           ...      NaN        41980
# 116                                      $200,000,000   132 min        91765
# 117                                      $160,000,000   132 min        64428
# 118                                      $150,000,000   108 min        53626
#
#      ...  Votes3044  Votes3044M  Votes3044F  Votes45A  Votes45AM  Votes45AF  \
# 1    ...        8.0         7.9         8.0       7.8        7.8        8.1
# 2    ...        7.5         7.5         7.5       7.3        7.3        7.5
# 3    ...        7.6         7.6         7.6       7.4        7.4        7.5
# 4    ...        7.6         7.6         7.7       7.6        7.5        7.8
# 5    ...        7.7         7.7         7.9       7.9        7.8        8.1
# ..   ...        ...         ...         ...       ...        ...        ...
# 114  ...        8.3         8.3         8.2       8.1        8.1        8.2
# 115  ...        7.6         7.6         7.7       7.4        7.4        7.5
# 116  ...        7.8         7.8         8.0       7.7        7.7        7.9
# 117  ...        7.7         7.6         7.8       7.6        7.5        7.7
# 118  ...        7.8         7.8         8.1       7.8        7.8        8.1
#
#      VotesIMDB  Votes1000  VotesUS VotesnUS
# 1          8.0        7.7      8.3      8.0
# 2          7.6        7.0      7.7      7.6
# 3          7.4        7.0      7.9      7.6
# 4          7.7        6.9      7.8      7.7
# 5          6.6        7.2      7.9      7.8
# ..         ...        ...      ...      ...
# 114        8.7        8.0      8.6      8.4
# 115        7.4        7.2      7.9      7.6
# 116        7.5        7.4      8.1      7.9
# 117        7.6        7.3      7.8      7.7
# 118        7.7        7.6      8.0      8.0
#
# [118 rows x 54 columns]

# %% [markdown]
# ## Supervised or Unsupervised Learning
# ## Classification or Regression
# ## Prediction or Inference

# %%
df = df[['Title', 'Rating', 'TotalVotes', 'MetaCritic', 'Budget', 'Runtime', 'VotesUS', 'VotesnUS']]
df
#regression (supervised learning) to predict IMDB rating from Metacritic Ratings, Budgets, Runtime, and Votes.
# Out:
#                                  Title  Rating TotalVotes  MetaCritic  \
# 1              12 Years a Slave (2013)     8.1    496,092        96.0
# 2                     127 Hours (2010)     7.6    297,075        82.0
# 3                         50/50 (2011)     7.7    283,935        72.0
# 4                    About Time (2013)     7.8    225,412         NaN
# 5                         Amour (2012)     7.9     76,121        94.0
# ..                                 ...     ...        ...         ...
# 114                    Whiplash (2014)     8.5    492,285        88.0
# 115              Wreck-It Ralph (2012)     7.7    295,125        72.0
# 116  X-Men: Days of Future Past (2014)     8.0    560,736        74.0
# 117          X-Men: First Class (2011)     7.8    556,713        65.0
# 118                    Zootopia (2016)     8.1    309,474        78.0
#
#                                                 Budget  Runtime VotesUS  \
# 1                                         $20,000,000   134 min     8.3
# 2                                         $18,000,000    94 min     7.7
# 3                                          $8,000,000   100 min     7.9
# 4                                         $12,000,000   123 min     7.8
# 5                                          $8,900,000   127 min     7.9
# ..                                                 ...      ...     ...
# 114                                        $3,300,000   107 min     8.6
# 115  Opening Weekend:         49,038,712           ...      NaN     7.9
# 116                                      $200,000,000   132 min     8.1
# 117                                      $160,000,000   132 min     7.8
# 118                                      $150,000,000   108 min     8.0
#
#     VotesnUS
# 1        8.0
# 2        7.6
# 3        7.6
# 4        7.7
# 5        7.8
# ..       ...
# 114      8.4
# 115      7.6
# 116      7.9
# 117      7.7
# 118      8.0
#
# [118 rows x 8 columns]

# %% [markdown]
# ## Data Cleaning (format)

# %%
df.dtypes
# Out:
# Title          object
# Rating        float64
# TotalVotes     object
# MetaCritic    float64
# Budget         object
# Runtime        object
# VotesUS        object
# VotesnUS       object
# dtype: object

# %%
df.TotalVotes = df.TotalVotes.str.replace(',', '')
df.TotalVotes = df.TotalVotes.astype(int)
# Total Votes column is ready.

df = df[(df.Budget.str.contains("Opening") == False) & (df.Budget.str.contains("Pathé") == False)]
df.Budget = df.Budget.str.replace('[^\x00-\x7F]','')
df.Budget = df.Budget.str.replace(',', '')
df.Budget = df.Budget.str.replace('$', '')
df.Budget = df.Budget.astype(int)
df.Budget = df.Budget.astype(int)
# Budget column is ready.

df.Runtime = df.Runtime.str.extract('(\d+)', expand=False)
# Runtime column is now ready.
# Out:
# C:\Riot Games\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-c9c8f7745e4c> in <module>
#       6 df.Budget = df.Budget.str.replace(',', '')
#       7 df.Budget = df.Budget.str.replace('$', '')
# ----> 8 df.Budget = df.Budget.astype(int)
#       9 # Budget column is ready.
#      10 df.Runtime = df.Runtime.str.extract('(\d+)', expand=False)
#
# C:\Riot Games\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# C:\Riot Games\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# C:\Riot Games\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# C:\Riot Games\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# C:\Riot Games\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'Production Co:        Path        BBC Films        Proud Films              See more'

# %%
df = df.dropna()
df.Runtime = df.Runtime.astype(int)
df.VotesnUS = df.VotesnUS.astype(float)
df.VotesUS = df.VotesUS.astype(float)

# %%
df.dtypes
# Out:
# Title          object
# Rating        float64
# TotalVotes      int32
# MetaCritic    float64
# Budget          int32
# Runtime         int32
# VotesUS       float64
# VotesnUS      float64
# dtype: object

# %%
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(df, figsize=(20,20))
plt.show()
