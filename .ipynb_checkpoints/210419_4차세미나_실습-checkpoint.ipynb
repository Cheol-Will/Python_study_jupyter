# %% [markdown]
# 출처: 테디노트 https://teddylee777.github.io/scikit-learn/gradient-descent 각색

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X1 = np.random.rand(100)
x2 = np.random.rand(100)
w1 = np.random.uniform(low=-1.0, high=1.0)
w2 = np.random.uniform(low=-1.0, high=1.0)
b = np.random.uniform(low=-1.0, high=1.0)

# %%
x1 = X1
a1 = w1
a2 = w2
rb = b

# %%
rng = 1
x1 = x1 * rng

# %%
y = 0.3 * x1 + 0.5 * x2 + rb

errors = []
w1_grad = []
w2_grad = []

num_epoch=1000
learning_rate= 0.5

# %%
for epoch in range(num_epoch):
    # 예측값
    y_hat = a1 * x1 + a2 * x2 + rb

    error = ((y_hat - y)**2).mean()
    if error < 0.00001:
        break
    
    # 미분값 적용 (Gradient)
    a1 = a1 - learning_rate * ((y_hat - y) * x1).mean()
    a2 = a2 - learning_rate * ((y_hat - y) * x2).mean()
    
    w1_grad.append(a1)
    w2_grad.append(a2)
    
    rb = rb - learning_rate * (y_hat - y).mean()
    
    errors.append(error)
    
    if epoch % 5 == 0:
        print("{0:2} a1 = {1:.5f}, a2 = {2:.5f}, rb = {3:.5f} error = {4:.5f}".format(epoch, a1, a2, rb, error))

print("----" * 15)
print("{0:2} a1 = {1:.1f}, a2 = {2:.1f}, rb = {3:.1f} error = {4:.5f}".format(epoch, a1, a2, rb, error))
# Out:
#  0 a1 = 0.30008, a2 = -0.63841, rb = 1.07069 error = 0.82630
#  5 a1 = 0.29943, a2 = -0.37159, rb = 1.13962 error = 0.07666
# 10 a1 = 0.25361, a2 = -0.21733, rb = 1.07872 error = 0.05124
# 15 a1 = 0.22409, a2 = -0.09277, rb = 1.02574 error = 0.03480
# 20 a1 = 0.20645, a2 = 0.00825, rb = 0.97972 error = 0.02401
# 25 a1 = 0.19730, a2 = 0.09049, rb = 0.93973 error = 0.01681
# 30 a1 = 0.19413, a2 = 0.15772, rb = 0.90495 error = 0.01193
# 35 a1 = 0.19507, a2 = 0.21289, rb = 0.87468 error = 0.00858
# 40 a1 = 0.19876, a2 = 0.25834, rb = 0.84834 error = 0.00623
# 45 a1 = 0.20418, a2 = 0.29594, rb = 0.82539 error = 0.00457
# 50 a1 = 0.21062, a2 = 0.32717, rb = 0.80540 error = 0.00338
# 55 a1 = 0.21754, a2 = 0.35319, rb = 0.78798 error = 0.00251
# 60 a1 = 0.22460, a2 = 0.37497, rb = 0.77279 error = 0.00188
# 65 a1 = 0.23154, a2 = 0.39325, rb = 0.75955 error = 0.00141
# 70 a1 = 0.23819, a2 = 0.40865, rb = 0.74800 error = 0.00106
# 75 a1 = 0.24447, a2 = 0.42166, rb = 0.73793 error = 0.00080
# 80 a1 = 0.25030, a2 = 0.43269, rb = 0.72914 error = 0.00061
# 85 a1 = 0.25567, a2 = 0.44207, rb = 0.72147 error = 0.00046
# 90 a1 = 0.26057, a2 = 0.45006, rb = 0.71477 error = 0.00035
# 95 a1 = 0.26501, a2 = 0.45689, rb = 0.70893 error = 0.00027
# 100 a1 = 0.26902, a2 = 0.46273, rb = 0.70383 error = 0.00020
# 105 a1 = 0.27261, a2 = 0.46775, rb = 0.69937 error = 0.00015
# 110 a1 = 0.27583, a2 = 0.47206, rb = 0.69549 error = 0.00012
# 115 a1 = 0.27869, a2 = 0.47577, rb = 0.69209 error = 0.00009
# 120 a1 = 0.28124, a2 = 0.47897, rb = 0.68913 error = 0.00007
# 125 a1 = 0.28350, a2 = 0.48174, rb = 0.68654 error = 0.00005
# 130 a1 = 0.28550, a2 = 0.48413, rb = 0.68428 error = 0.00004
# 135 a1 = 0.28726, a2 = 0.48620, rb = 0.68230 error = 0.00003
# 140 a1 = 0.28882, a2 = 0.48799, rb = 0.68058 error = 0.00002
# 145 a1 = 0.29019, a2 = 0.48955, rb = 0.67907 error = 0.00002
# 150 a1 = 0.29140, a2 = 0.49090, rb = 0.67776 error = 0.00001
# 155 a1 = 0.29246, a2 = 0.49207, rb = 0.67661 error = 0.00001
# ------------------------------------------------------------
# 156 a1 = 0.3, a2 = 0.5, rb = 0.7 error = 0.00001

# %%
plt.figure(figsize=(10, 7))

plt.plot(errors)

# %%
plt.figure(figsize=(10, 7))

plt.hlines(y=0.3, xmin=0, xmax=len(w1_grad), color='r')
plt.plot(w1_grad, color='g')
plt.ylim(0, 1)
plt.title('W1', fontsize=16)
plt.legend(['W1 Change', 'W1'])
plt.show()

# %%
plt.figure(figsize=(10, 7))

plt.hlines(y=0.5, xmin=0, xmax=len(w2_grad), color='r')
plt.plot(w2_grad, color='g')
plt.ylim(0, 1)
plt.title('W2', fontsize=16)
plt.legend(['W2 Change', 'W2'])
plt.show()
