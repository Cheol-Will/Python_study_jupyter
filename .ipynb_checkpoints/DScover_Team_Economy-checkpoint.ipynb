# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("1인가구 거처종류별 통계.txt", sep = "\t", encoding = "utf-8")

# %%
data
# Out:
#       기간  자치구  성별         합계 주택(거처)의 종류 주택(거처)의 종류.1 주택(거처)의 종류.2  \
# 0     기간  자치구  성별         합계          계         단독주택          아파트
# 1   2019   합계   계  1,299,787  1,100,060      524,735      286,571
# 2   2019   합계  남자    611,561    509,621      268,965      109,124
# 3   2019   합계  여자    688,226    590,439      255,770      177,447
# 4   2019  종로구   계     24,671     20,018       11,354        3,336
# ..   ...  ...  ..        ...        ...          ...          ...
# 74  2019  송파구  남자     31,036     25,109        8,457        5,235
# 75  2019  송파구  여자     37,825     31,297        7,888        9,274
# 76  2019  강동구   계     45,188     39,516       18,661        9,843
# 77  2019  강동구  남자     21,674     18,697        9,839        3,860
# 78  2019  강동구  여자     23,514     20,819        8,822        5,983
#
#    주택(거처)의 종류.3 주택(거처)의 종류.4 주택(거처)의 종류.5  주택이외의 거처
# 0          연립주택        다세대주택  비거주용 건물내 주택  주택이외의 거처
# 1        19,555      223,927       45,272   199,727
# ...

# %%
data_2019 = pd.read_csv("오피스텔(전월세)_실거래가_2019.csv", encoding = "cp949")
data_2019
# Out:
#                  시군구      번지    본번  부번          단지명 전월세구분  전용면적(㎡)    계약년월  \
# 0      서울특별시 강남구 개포동   157-9   157   9  \t(157-9)\t    월세    36.96  201905
# 1      서울특별시 강남구 개포동   157-9   157   9  \t(157-9)\t    전세    36.96  201911
# 2      서울특별시 강남구 개포동  1229-6  1229   6     CCRU오피스텔    전세    22.12  201910
# 3      서울특별시 강남구 개포동  1229-6  1229   6     CCRU오피스텔    전세    22.12  201911
# 4      서울특별시 강남구 개포동  1229-6  1229   6     CCRU오피스텔    전세    20.51  201912
# ...              ...     ...   ...  ..          ...   ...      ...     ...
# 48273  서울특별시 중랑구 중화동   208-4   208   4    중화동 범양프레체    전세    22.21  201911
# 48274  서울특별시 중랑구 중화동   208-4   208   4    중화동 범양프레체    월세    22.21  201911
# 48275  서울특별시 중랑구 중화동   208-4   208   4    중화동 범양프레체    전세    22.21  201911
# 48276  서울특별시 중랑구 중화동   208-4   208   4    중화동 범양프레체    월세    22.21  201912
# 48277  서울특별시 중랑구 중화동   307-4   307   4        화인하우스    전세    76.88  201907
#
#        계약일 보증금(만원) 월세(만원)  층    건축년도         도로명
# ...

# %%
data_2020 = pd.read_csv("오피스텔(전월세)_실거래가_2020.csv", encoding = "utf-8")
data_2020
# Out:
#                  시군구      번지    본번  부번        단지명 전월세구분  전용면적(㎡)    계약년월  계약일  \
# 0      서울특별시 강남구 개포동  1237-3  1237   3   (1237-3)    월세    29.51  202004   11
# 1      서울특별시 강남구 개포동  1237-3  1237   3   (1237-3)    월세    29.95  202005   30
# 2      서울특별시 강남구 개포동  1237-3  1237   3   (1237-3)    월세    29.95  202006    3
# 3      서울특별시 강남구 개포동  1237-3  1237   3   (1237-3)    월세    34.12  202006    3
# 4      서울특별시 강남구 개포동  1237-3  1237   3   (1237-3)    월세    34.12  202008   17
# ...              ...     ...   ...  ..        ...   ...      ...     ...  ...
# 49899  서울특별시 중랑구 중화동   208-4   208   4  중화동 범양프레체    월세    22.21  202009   19
# 49900  서울특별시 중랑구 중화동   208-4   208   4  중화동 범양프레체    전세    22.21  202009   26
# 49901  서울특별시 중랑구 중화동   208-4   208   4  중화동 범양프레체    월세    22.21  202010   15
# 49902  서울특별시 중랑구 중화동  305-59   305  59     탑클래스2차    월세    20.65  202012    2
# 49903  서울특별시 중랑구 중화동  305-59   305  59     탑클래스2차    월세    23.32  202012   14
#
# ...

# %%
data_2020[data_2020["전월세구분"] == "전세"].head()
# Out:
#               시군구      번지    본번  부번       단지명 전월세구분  전용면적(㎡)    계약년월  계약일  \
# 5   서울특별시 강남구 개포동  1237-3  1237   3  (1237-3)    전세    29.51  202009    8
# 13  서울특별시 강남구 개포동  1229-6  1229   6  CCRU오피스텔    전세    42.23  202001   29
# 14  서울특별시 강남구 개포동  1229-6  1229   6  CCRU오피스텔    전세    50.04  202002    3
# 15  서울특별시 강남구 개포동  1229-6  1229   6  CCRU오피스텔    전세    50.04  202002    5
# 16  서울특별시 강남구 개포동  1229-6  1229   6  CCRU오피스텔    전세    42.23  202002    8
#
#    보증금(만원) 월세(만원)  층    건축년도        도로명
# 5    3,000      0  6  2020.0  논현로20길 12
# 13  28,500      0  3  2019.0     논현로 78
# 14  32,000      0  3  2019.0     논현로 78
# 15  31,500      0  2  2019.0     논현로 78
# 16  29,000      0  4  2019.0     논현로 78

# %%
data_2020
